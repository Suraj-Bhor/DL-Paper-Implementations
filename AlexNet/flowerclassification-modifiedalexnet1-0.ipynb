jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/11545123_50a340b473_m.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/10437652486_aa86c14985.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/34575269471_fe82b32aa9_n.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/8475758_4c861ab268_m.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/8223949_2928d3f6f6_n.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/8719032054_9a3ce4f0ff.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/19602790836_912d38aaa8.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/13887031789_97437f246b.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/1074999133_1e4a1e042e.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/5797606814_ccac615312_m.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/2553703483_558d12668c_n.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/19437710780_c5f2156438.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/6994925894_030e157fe0.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/2481428401_bed64dd043.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/4632251871_9f324a7bb5.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/33892886253_7c74efdd7a_n.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/2326334426_2dc74fceb1.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/14053184940_7ced69250f_n.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/854593001_c57939125f_n.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/8963359346_65ca69c59d_n.jpg
# /kaggle/input/flowers-recognition/flowers/dandelion/33914172633_592a6eb74f_n.jpg

# %% [markdown]
# ## 2. Importing required modules

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
 
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

# %%
#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from keras.preprocessing.image import ImageDataGenerator

#dl libraraies
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD, Adam
from keras.utils import to_categorical

# specifically for cnn
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

 
import tensorflow as tf
import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 3. Preparing the data.
# ### 3.1 Making the functions to get the training and validation set from the Images

# %%
X=[]
Z=[]
IMG_SIZE=128
FLOWER_DAISY_DIR='../input/flowers-recognition/flowers/daisy'
FLOWER_SUNFLOWER_DIR='../input/flowers-recognition/flowers/sunflower'
FLOWER_TULIP_DIR='../input/flowers-recognition/flowers/tulip'
FLOWER_DANDI_DIR='../input/flowers-recognition/flowers/dandelion'
FLOWER_ROSE_DIR='../input/flowers-recognition/flowers/rose'

# %%
def assign_label(img,flower_type):
    return flower_type

# %%
def make_train_data(flower_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,flower_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        if img is not None:
            img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
            X.append(np.array(img))
            Z.append(str(label))

# %%
make_train_data('Daisy',FLOWER_DAISY_DIR)
print(len(X))
# Out:
# 100%|██████████| 769/769 [00:03<00:00, 228.11it/s]
# 769

# %%
make_train_data('Sunflower',FLOWER_SUNFLOWER_DIR)
print(len(X))
# Out:
# 100%|██████████| 734/734 [00:03<00:00, 201.37it/s]
# 1503

# %%
make_train_data('tulip',FLOWER_TULIP_DIR)
print(len(X))
# Out:
# 100%|██████████| 984/984 [00:05<00:00, 196.69it/s]
# 2487

# %%
make_train_data('rose',FLOWER_ROSE_DIR)
print(len(X))
# Out:
# 100%|██████████| 784/784 [00:03<00:00, 232.90it/s]
# 3271

# %%
make_train_data('dandelion',FLOWER_DANDI_DIR)
print(len(X))
# Out:
# 100%|██████████| 1055/1055 [00:05<00:00, 202.15it/s]
# 4323

# %% [markdown]
# ### 3.2 Visualizing random images

# %%
fig,ax=plt.subplots(5,3)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (3):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Flower: '+Z[l])
        
plt.tight_layout()

# %% [markdown]
# ### 3.3 Label Encoding the Y array (i.e. Daisy->0, Rose->1 etc...) & then One Hot Encoding

# %%
le = LabelEncoder()
Y = le.fit(Z)
Y = le.transform(Z)
Y = to_categorical(Y, 5)
X = np.array(X)
X = X / 255

# %% [markdown]
# ### 3.4  Splitting into Training and Validation Sets

# %%
x_train,x_test,y_train,y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
print("Shape of x_train:", x_train.shape)
print("Shape of y_train:", y_train.shape)

print("Shape of x_test:", x_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of x_train: (3242, 128, 128, 3)
# Shape of y_train: (3242, 5)
# Shape of x_test: (1081, 128, 128, 3)
# Shape of y_test: (1081, 5)

# %% [markdown]
# ### 3.5 Setting the random seeds

# %%
np.random.seed(42)
rn.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## 4. Building the Model
# ### 4.1 Specifying the AlexNet model in Keras

# %%
model = Sequential()

model.add(Conv2D(filters=96, kernel_size=(11,11),strides=(4,4), padding='valid', activation='relu',input_shape=(IMG_SIZE,IMG_SIZE,3)))
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(filters=256, kernel_size=(5,5),strides=(1,1), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3,3), strides=2))
model.add(BatchNormalization())

model.add(Conv2D(filters=384, kernel_size=(3,3),strides=(1,1), padding='same', activation='relu'))

model.add(Conv2D(filters=384, kernel_size=(3,3),strides=(1,1), padding='same', activation='relu'))

model.add(Conv2D(filters=256, kernel_size=(3,3),strides=(1,1), padding='same', activation='relu'))

model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2)))

model.add(Flatten())

model.add(Dense(4096))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(4096))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### 4.2 Using Data Augmentation for Regularization

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

from keras.callbacks import ReduceLROnPlateau, EarlyStopping

red_lr = ReduceLROnPlateau(monitor='val_accuracy',patience=3,verbose=1,factor=0.1)

early  = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')

# %% [markdown]
# ### 4.3 Specifying the bacth size and epochs and then compiling the model.

# %%
batch_size=128
epochs=50
model.compile(optimizer=SGD(lr=0.01, momentum=0.9),loss='categorical_crossentropy',metrics=['accuracy']) # Original AlexNet Parameters
#model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ### 4.4 Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 30, 30, 96)        34944
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 96)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 96)        384
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 256)       614656
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 384)         885120
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 384)         1327488
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 256)         884992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              4198400
# _________________________________________________________________
# activation_1 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_2 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 20485
# =================================================================
# Total params: 24,748,805
# Trainable params: 24,748,101
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# ### 4.5 Training the model and making predictions on the validation set.

# %%
History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs=epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // 128, callbacks=[red_lr,early])
# Out:
# Epoch 1/50
# 25/25 [==============================] - 15s 595ms/step - loss: 1.4314 - accuracy: 0.3683 - val_loss: 1.5581 - val_accuracy: 0.2202
# Epoch 2/50
# 25/25 [==============================] - 12s 479ms/step - loss: 1.1745 - accuracy: 0.5260 - val_loss: 1.4774 - val_accuracy: 0.3053
# Epoch 3/50
# 25/25 [==============================] - 12s 493ms/step - loss: 1.0777 - accuracy: 0.5514 - val_loss: 1.4423 - val_accuracy: 0.4940
# Epoch 4/50
# 25/25 [==============================] - 13s 522ms/step - loss: 1.0766 - accuracy: 0.5713 - val_loss: 1.2930 - val_accuracy: 0.4773
# Epoch 5/50
# 25/25 [==============================] - 13s 501ms/step - loss: 1.0318 - accuracy: 0.5881 - val_loss: 1.2233 - val_accuracy: 0.5134
# Epoch 6/50
# 25/25 [==============================] - 12s 487ms/step - loss: 0.9645 - accuracy: 0.6222 - val_loss: 1.1644 - val_accuracy: 0.5689
# Epoch 7/50
# 25/25 [==============================] - 12s 488ms/step - loss: 0.9174 - accuracy: 0.6481 - val_loss: 1.4049 - val_accuracy: 0.4033
# Epoch 8/50
# 25/25 [==============================] - 12s 471ms/step - loss: 0.9013 - accuracy: 0.6496 - val_loss: 1.2714 - val_accuracy: 0.4246
# Epoch 9/50
# 25/25 [==============================] - 13s 537ms/step - loss: 0.8340 - accuracy: 0.6708 - val_loss: 1.3233 - val_accuracy: 0.4699
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# Epoch 10/50
# 25/25 [==============================] - 12s 488ms/step - loss: 0.8733 - accuracy: 0.6731 - val_loss: 1.0714 - val_accuracy: 0.5865
# Epoch 11/50
# 25/25 [==============================] - 12s 490ms/step - loss: 0.7847 - accuracy: 0.7052 - val_loss: 0.9267 - val_accuracy: 0.6549
# Epoch 12/50
# 25/25 [==============================] - 12s 466ms/step - loss: 0.7435 - accuracy: 0.7160 - val_loss: 0.8479 - val_accuracy: 0.6744
# Epoch 13/50
# 25/25 [==============================] - 12s 491ms/step - loss: 0.7382 - accuracy: 0.7184 - val_loss: 0.8999 - val_accuracy: 0.6698
# Epoch 14/50
# 25/25 [==============================] - 14s 545ms/step - loss: 0.7131 - accuracy: 0.7338 - val_loss: 0.8607 - val_accuracy: 0.6707
# Epoch 15/50
# 25/25 [==============================] - 12s 484ms/step - loss: 0.7230 - accuracy: 0.7241 - val_loss: 0.7443 - val_accuracy: 0.7105
# Epoch 16/50
# 25/25 [==============================] - 12s 485ms/step - loss: 0.6966 - accuracy: 0.7328 - val_loss: 0.7401 - val_accuracy: 0.7317
# Epoch 17/50
# 25/25 [==============================] - 12s 491ms/step - loss: 0.7056 - accuracy: 0.7328 - val_loss: 0.7169 - val_accuracy: 0.7308
# Epoch 18/50
# 25/25 [==============================] - 13s 507ms/step - loss: 0.6726 - accuracy: 0.7489 - val_loss: 0.7352 - val_accuracy: 0.7197
# Epoch 19/50
# 25/25 [==============================] - 13s 506ms/step - loss: 0.6713 - accuracy: 0.7431 - val_loss: 0.7503 - val_accuracy: 0.7336
# Epoch 20/50
# 25/25 [==============================] - 12s 466ms/step - loss: 0.6682 - accuracy: 0.7490 - val_loss: 0.7405 - val_accuracy: 0.7206
# Epoch 21/50
# 25/25 [==============================] - 13s 519ms/step - loss: 0.6592 - accuracy: 0.7519 - val_loss: 0.7107 - val_accuracy: 0.7382
# Epoch 22/50
# 25/25 [==============================] - 12s 484ms/step - loss: 0.6838 - accuracy: 0.7380 - val_loss: 0.8420 - val_accuracy: 0.6873
# Epoch 23/50
# 25/25 [==============================] - 12s 499ms/step - loss: 0.6454 - accuracy: 0.7559 - val_loss: 0.6955 - val_accuracy: 0.7419
# Epoch 24/50
# 25/25 [==============================] - 13s 517ms/step - loss: 0.6479 - accuracy: 0.7582 - val_loss: 0.8031 - val_accuracy: 0.7160
# Epoch 25/50
# 25/25 [==============================] - 12s 482ms/step - loss: 0.6442 - accuracy: 0.7614 - val_loss: 0.6830 - val_accuracy: 0.7382
# Epoch 26/50
# 25/25 [==============================] - 12s 492ms/step - loss: 0.6368 - accuracy: 0.7669 - val_loss: 0.6883 - val_accuracy: 0.7447
# Epoch 27/50
# 25/25 [==============================] - 12s 483ms/step - loss: 0.6251 - accuracy: 0.7640 - val_loss: 0.7010 - val_accuracy: 0.7438
# Epoch 28/50
# 25/25 [==============================] - 13s 515ms/step - loss: 0.6230 - accuracy: 0.7704 - val_loss: 0.7262 - val_accuracy: 0.7336
# Epoch 29/50
# 25/25 [==============================] - 13s 522ms/step - loss: 0.6306 - accuracy: 0.7647 - val_loss: 0.7295 - val_accuracy: 0.7299
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# Epoch 30/50
# 25/25 [==============================] - 12s 467ms/step - loss: 0.6412 - accuracy: 0.7540 - val_loss: 0.7306 - val_accuracy: 0.7151
# Epoch 31/50
# 25/25 [==============================] - 12s 493ms/step - loss: 0.6174 - accuracy: 0.7739 - val_loss: 0.6521 - val_accuracy: 0.7530
# Epoch 32/50
# 25/25 [==============================] - 12s 483ms/step - loss: 0.5965 - accuracy: 0.7739 - val_loss: 0.6488 - val_accuracy: 0.7530
# Epoch 33/50
# 25/25 [==============================] - 13s 536ms/step - loss: 0.5895 - accuracy: 0.7828 - val_loss: 0.6393 - val_accuracy: 0.7530
# Epoch 34/50
# 25/25 [==============================] - 12s 490ms/step - loss: 0.5971 - accuracy: 0.7777 - val_loss: 0.6403 - val_accuracy: 0.7558
# Epoch 35/50
# 25/25 [==============================] - 12s 498ms/step - loss: 0.5920 - accuracy: 0.7753 - val_loss: 0.6362 - val_accuracy: 0.7567
# Epoch 36/50
# 25/25 [==============================] - 12s 475ms/step - loss: 0.5964 - accuracy: 0.7754 - val_loss: 0.6368 - val_accuracy: 0.7613
# Epoch 37/50
# 25/25 [==============================] - 13s 501ms/step - loss: 0.6058 - accuracy: 0.7700 - val_loss: 0.6295 - val_accuracy: 0.7613
# Epoch 38/50
# 25/25 [==============================] - 13s 522ms/step - loss: 0.5721 - accuracy: 0.7871 - val_loss: 0.6321 - val_accuracy: 0.7567
# Epoch 39/50
# 25/25 [==============================] - 13s 503ms/step - loss: 0.6061 - accuracy: 0.7807 - val_loss: 0.6277 - val_accuracy: 0.7604
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# Epoch 40/50
# 25/25 [==============================] - 12s 478ms/step - loss: 0.5952 - accuracy: 0.7820 - val_loss: 0.6272 - val_accuracy: 0.7567
# Epoch 41/50
# 25/25 [==============================] - 13s 505ms/step - loss: 0.5903 - accuracy: 0.7820 - val_loss: 0.6282 - val_accuracy: 0.7567
# Epoch 42/50
# 25/25 [==============================] - 12s 483ms/step - loss: 0.5938 - accuracy: 0.7797 - val_loss: 0.6286 - val_accuracy: 0.7567
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 9.99999883788405e-07.
# Epoch 43/50
# 25/25 [==============================] - 14s 549ms/step - loss: 0.5634 - accuracy: 0.7944 - val_loss: 0.6289 - val_accuracy: 0.7576
# Epoch 44/50
# 25/25 [==============================] - 12s 500ms/step - loss: 0.5844 - accuracy: 0.7839 - val_loss: 0.6292 - val_accuracy: 0.7567
# Epoch 45/50
# 25/25 [==============================] - 12s 490ms/step - loss: 0.6044 - accuracy: 0.7842 - val_loss: 0.6293 - val_accuracy: 0.7558
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 9.99999883788405e-08.
# Epoch 46/50
# 25/25 [==============================] - 12s 498ms/step - loss: 0.5941 - accuracy: 0.7775 - val_loss: 0.6294 - val_accuracy: 0.7558
# Epoch 47/50
# 25/25 [==============================] - 13s 511ms/step - loss: 0.5964 - accuracy: 0.7826 - val_loss: 0.6294 - val_accuracy: 0.7558
# Epoch 48/50
# 25/25 [==============================] - 13s 511ms/step - loss: 0.5694 - accuracy: 0.7829 - val_loss: 0.6292 - val_accuracy: 0.7576
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 9.999998695775504e-09.
# Epoch 49/50
# 25/25 [==============================] - 12s 498ms/step - loss: 0.5841 - accuracy: 0.7864 - val_loss: 0.6293 - val_accuracy: 0.7558
# Epoch 50/50
# 25/25 [==============================] - 12s 493ms/step - loss: 0.5839 - accuracy: 0.7868 - val_loss: 0.6295 - val_accuracy: 0.7558

# %% [markdown]
# ## 5. Plotting and evaluating the model performance

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# ## 6. Visualizing Predictons on the Validation Set

# %%
# getting predictions on val set.
pred=model.predict(x_test)
pred_digits=np.argmax(pred,axis=1)
print(len(pred_digits))
print(pred_digits.shape)

print(y_test[0])
# Out:
# 1081
# (1081,)
# [0. 1. 0. 0. 0.]

# %% [markdown]
# ## 7. Calculating number of correctly and incorrectly classified number of images.****

# %%
i=0
prop_class=[]
mis_class=[]

for i in range(len(y_test)):
    if(np.argmax(y_test[i])==pred_digits[i]):
        prop_class.append(i)

i=0
for i in range(len(y_test)):
    if(not np.argmax(y_test[i])==pred_digits[i]):
        mis_class.append(i)

print("Number of correctly classified images: %d" %(len(prop_class)))
print("Number of incorrectly classified images: %d" %(len(mis_class)))
# Out:
# Number of correctly classified images: 817
# Number of incorrectly classified images: 264

# %%
print(y_test[0])
(np.argmax(y_test,axis=1)).shape
# Out:
# [0. 1. 0. 0. 0.]
# (1081,)

# %%
print(pred_digits.shape)
le.inverse_transform([pred_digits[prop_class[10]]])
le.inverse_transform(np.argmax(y_test,axis=1))
# Out:
# (1081,)
# array(['Sunflower', 'Sunflower', 'Sunflower', ..., 'tulip', 'tulip',
#        'rose'], dtype='<U9')

# %% [markdown]
# ## 8. Correctly classified images visualized

# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

count=0
fig,ax=plt.subplots(4,2)
fig.set_size_inches(15,15)
for i in range (4):
    for j in range (2):
        ax[i,j].imshow(x_test[prop_class[count]])
        ax[i,j].set_title("Predicted Flower : "+str(le.inverse_transform([pred_digits[prop_class[count]]]))+"\n"+"Actual Flower : "+str(le.inverse_transform(np.argmax([y_test[prop_class[count]]],axis=1))))
        plt.tight_layout()
        count+=1

# %% [markdown]
# ## 9. Incorrectly classified images visualized

# %%
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

count=0
fig,ax=plt.subplots(4,2)
fig.set_size_inches(15,15)
for i in range (4):
    for j in range (2):
        ax[i,j].imshow(x_test[mis_class[count]])
        ax[i,j].set_title("Predicted Flower : "+str(le.inverse_transform([pred_digits[mis_class[count]]]))+"\n"+"Actual Flower : "+str(le.inverse_transform(np.argmax([y_test[mis_class[count]]],axis=1))))
        plt.tight_layout()
        count+=1
